# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('full_dataset.csv')

# %%
df.describe()
# Out:
#             Price  swimming_pool  train_station  bus_station  school_dist  \
# count  500.000000     500.000000     500.000000   500.000000   500.000000
# mean     2.568000       0.522000       3.002000     2.960000     2.546000
# std      1.100818       0.500016       1.426206     1.393659     1.116412
# min      1.000000       0.000000       1.000000     1.000000     1.000000
# 25%      2.000000       0.000000       2.000000     2.000000     2.000000
# 50%      3.000000       1.000000       3.000000     3.000000     3.000000
# 75%      4.000000       1.000000       4.000000     4.000000     4.000000
# max      4.000000       1.000000       5.000000     5.000000     4.000000
#
#        near_park_dist  parking_on_street  dist_local_market  \
# count      500.000000         500.000000         500.000000
# mean         3.002000           0.536000           3.062000
# std          1.399254           0.499202           1.423449
# min          1.000000           0.000000           1.000000
# 25%          2.000000           0.000000           2.000000
# 50%          3.000000           1.000000           3.000000
# 75%          4.000000           1.000000           4.000000
# max          5.000000           1.000000           5.000000
#
#        dist_health_center   dist_bank         NRM         Tax  age_of_house  \
# count          500.000000  500.000000  500.000000   500.00000    500.000000
# mean             2.908000    3.028000    3.070000  3481.97400     10.720000
# std              1.406945    1.395389    1.438485   839.01349      5.901122
# min              1.000000    1.000000    1.000000  2000.00000      1.000000
# 25%              2.000000    2.000000    2.000000  2759.25000      6.000000
# 50%              3.000000    3.000000    3.000000  3492.50000     11.000000
# 75%              4.000000    4.000000    4.000000  4137.50000     16.000000
# max              5.000000    5.000000    5.000000  4998.00000     20.000000
#
#         area_type  dist_police_station   dist_mall    floor_no  dist_worship
# count  500.000000           500.000000  500.000000  500.000000    500.000000
# mean     0.510000             2.064000    1.924000   13.306000    589.722000
# std      0.500401             0.832641    0.826796    7.369191    342.595376
# min      0.000000             1.000000    1.000000    5.000000      3.000000
# 25%      0.000000             1.000000    1.000000    7.000000    308.500000
# 50%      1.000000             2.000000    2.000000   10.000000    583.500000
# 75%      1.000000             3.000000    3.000000   19.000000    860.250000
# max      1.000000             3.000000    3.000000   29.000000   1197.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                500 non-null    int64
#  1   swimming_pool        500 non-null    int64
#  2   train_station        500 non-null    int64
#  3   bus_station          500 non-null    int64
#  4   school_dist          500 non-null    int64
#  5   near_park_dist       500 non-null    int64
#  6   parking_on_street    500 non-null    int64
#  7   dist_local_market    500 non-null    int64
#  8   dist_health_center   500 non-null    int64
#  9   dist_bank            500 non-null    int64
#  10  NRM                  500 non-null    int64
#  11  Tax                  500 non-null    int64
#  12  age_of_house         500 non-null    int64
#  13  area_type            500 non-null    int64
#  14  dist_police_station  500 non-null    int64
#  15  dist_mall            500 non-null    int64
#  16  floor_no             500 non-null    int64
#  17  dist_worship         500 non-null    int64
# dtypes: int64(18)
# memory usage: 70.4 KB

# %%
df_copy = df.copy(deep=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Price  swimming_pool  train_station  bus_station  school_dist  \
# 0        3              0              4            1            4
# 1        3              0              3            1            3
# 2        2              0              2            4            2
# 3        3              1              2            1            4
# 4        3              0              4            4            3
# ..     ...            ...            ...          ...          ...
# 495      4              1              1            5            3
# 496      1              0              5            5            4
# 497      1              0              2            4            3
# 498      3              1              3            5            4
# 499      3              1              1            3            2
#
#      near_park_dist  parking_on_street  dist_local_market  dist_health_center  \
# 0                 2                  0                  4                   1
# 1                 4                  0                  2                   3
# 2                 4                  1                  2                   3
# 3                 3                  0                  1                   1
# 4                 5                  0                  4                   3
# ..              ...                ...                ...                 ...
# 495               1                  0                  4                   3
# 496               3                  1                  1                   4
# 497               5                  1                  4                   1
# 498               1                  1                  4                   5
# 499               3                  1                  2                   2
#
#      dist_bank  NRM   Tax  age_of_house  area_type  dist_police_station  \
# 0            4    5  4220            19          1                    2
# 1            5    4  4930            19          1                    1
# 2            3    5  4617            13          0                    3
# 3            4    4  2973             1          0                    3
# 4            4    5  2009             6          1                    3
# ..         ...  ...   ...           ...        ...                  ...
# 495          5    3  2738            16          0                    3
# 496          1    5  2211            17          1                    1
# 497          1    5  2006             9          1                    3
# 498          4    2  2760            15          0                    2
# 499          1    3  4553            20          0                    2
#
#      dist_mall  floor_no  dist_worship
# 0            1         6           275
# 1            1         7           559
# 2            1        10           946
# 3            2        14          1013
# 4            1        11          1152
# ..         ...       ...           ...
# 495          3         5           536
# 496          2         7           356
# 497          3        17           395
# 498          3        10           766
# 499          1        16            16
#
# [500 rows x 18 columns]>

# %%
from sklearn.model_selection import train_test_split
train_set, test_set= train_test_split(df_copy,test_size=0.2,random_state=42)

# %%
names=['train_station','bus_station','school_dist','dist_health_center','parking_on_street'
       'dist_local_market','NRM','age_of_house','area_type','floor_no','Tax'
       ,'dist_mall']

# %%
corr_matrix = df_copy.corr(method='pearson')

# %%
corr_matrix
# Out:
#                         Price  swimming_pool  train_station  bus_station  \
# Price                1.000000      -0.022748      -0.019872    -0.088355
# swimming_pool       -0.022748       1.000000      -0.060481    -0.024617
# train_station       -0.019872      -0.060481       1.000000    -0.092717
# bus_station         -0.088355      -0.024617      -0.092717     1.000000
# school_dist         -0.071853       0.109473      -0.044739    -0.034879
# near_park_dist      -0.050178       0.007098      -0.035149     0.137747
# parking_on_street    0.046591       0.040978      -0.015582    -0.006568
# dist_local_market   -0.017403      -0.011775       0.072987     0.011354
# dist_health_center  -0.015361       0.011429      -0.000907     0.063530
# dist_bank           -0.015593       0.105388       0.025146    -0.053009
# NRM                 -0.013769      -0.025828       0.018491    -0.000600
# Tax                 -0.059477      -0.020021       0.022835    -0.054262
# age_of_house         0.012809      -0.049525      -0.096845     0.034212
# area_type            0.000582      -0.008890       0.037880     0.037931
# dist_police_station -0.002571       0.006238       0.008330     0.057474
# dist_mall           -0.042751       0.013747      -0.025363    -0.023514
# floor_no            -0.040244      -0.010805      -0.031520     0.063636
# dist_worship         0.066735       0.074222       0.008032     0.004971
#
#                      school_dist  near_park_dist  parking_on_street  \
# Price                  -0.071853       -0.050178           0.046591
# swimming_pool           0.109473        0.007098           0.040978
# train_station          -0.044739       -0.035149          -0.015582
# bus_station            -0.034879        0.137747          -0.006568
# school_dist             1.000000       -0.068692          -0.065904
# near_park_dist         -0.068692        1.000000          -0.038834
# parking_on_street      -0.065904       -0.038834           1.000000
# dist_local_market      -0.040260       -0.014148           0.049027
# dist_health_center     -0.018990        0.084583          -0.012395
# dist_bank               0.044196       -0.054427          -0.038850
# NRM                    -0.033830        0.049712          -0.074680
# Tax                     0.035751        0.031721          -0.042699
# age_of_house           -0.012946       -0.015222          -0.031946
# area_type               0.067332        0.047196           0.034657
# dist_police_station    -0.057069       -0.013871          -0.015197
# dist_mall              -0.002718        0.031312           0.021208
# floor_no               -0.000618       -0.003363           0.038129
# dist_worship            0.040611        0.018261           0.011712
#
#                      dist_local_market  dist_health_center  dist_bank  \
# Price                        -0.017403           -0.015361  -0.015593
# swimming_pool                -0.011775            0.011429   0.105388
# train_station                 0.072987           -0.000907   0.025146
# bus_station                   0.011354            0.063530  -0.053009
# school_dist                  -0.040260           -0.018990   0.044196
# near_park_dist               -0.014148            0.084583  -0.054427
# parking_on_street             0.049027           -0.012395  -0.038850
# dist_local_market             1.000000           -0.016158   0.004169
# dist_health_center           -0.016158            1.000000   0.042145
# dist_bank                     0.004169            0.042145   1.000000
# NRM                          -0.012890           -0.095830  -0.016953
# Tax                          -0.025754           -0.037909   0.087859
# age_of_house                  0.001117           -0.006729   0.051819
# area_type                     0.042736           -0.021462   0.019688
# dist_police_station           0.006790           -0.051416   0.050199
# dist_mall                     0.061906            0.019819  -0.102373
# floor_no                      0.027418            0.004460  -0.014282
# dist_worship                 -0.072076            0.016249   0.018306
#
#                           NRM       Tax  age_of_house  area_type  \
# Price               -0.013769 -0.059477      0.012809   0.000582
# swimming_pool       -0.025828 -0.020021     -0.049525  -0.008890
# train_station        0.018491  0.022835     -0.096845   0.037880
# bus_station         -0.000600 -0.054262      0.034212   0.037931
# school_dist         -0.033830  0.035751     -0.012946   0.067332
# near_park_dist       0.049712  0.031721     -0.015222   0.047196
# parking_on_street   -0.074680 -0.042699     -0.031946   0.034657
# dist_local_market   -0.012890 -0.025754      0.001117   0.042736
# dist_health_center  -0.095830 -0.037909     -0.006729  -0.021462
# dist_bank           -0.016953  0.087859      0.051819   0.019688
# NRM                  1.000000  0.018321      0.014118   0.019906
# Tax                  0.018321  1.000000     -0.045587  -0.010059
# age_of_house         0.014118 -0.045587      1.000000   0.084424
# area_type            0.019906 -0.010059      0.084424   1.000000
# dist_police_station -0.000402  0.029825      0.055860   0.012890
# dist_mall           -0.003943 -0.004226      0.072438  -0.003003
# floor_no            -0.023576 -0.012670      0.055016   0.005962
# dist_worship         0.033258 -0.028906     -0.003941   0.044314
#
#                      dist_police_station  dist_mall  floor_no  dist_worship
# Price                          -0.002571  -0.042751 -0.040244      0.066735
# swimming_pool                   0.006238   0.013747 -0.010805      0.074222
# train_station                   0.008330  -0.025363 -0.031520      0.008032
# bus_station                     0.057474  -0.023514  0.063636      0.004971
# school_dist                    -0.057069  -0.002718 -0.000618      0.040611
# near_park_dist                 -0.013871   0.031312 -0.003363      0.018261
# parking_on_street              -0.015197   0.021208  0.038129      0.011712
# dist_local_market               0.006790   0.061906  0.027418     -0.072076
# dist_health_center             -0.051416   0.019819  0.004460      0.016249
# dist_bank                       0.050199  -0.102373 -0.014282      0.018306
# NRM                            -0.000402  -0.003943 -0.023576      0.033258
# Tax                             0.029825  -0.004226 -0.012670     -0.028906
# age_of_house                    0.055860   0.072438  0.055016     -0.003941
# area_type                       0.012890  -0.003003  0.005962      0.044314
# dist_police_station             1.000000  -0.051141  0.066042     -0.018084
# dist_mall                      -0.051141   1.000000 -0.019857     -0.029372
# floor_no                        0.066042  -0.019857  1.000000     -0.009334
# dist_worship                   -0.018084  -0.029372 -0.009334      1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
result =corr_matrix['Price'].sort_values(ascending=True)

# %%
result
# Out:
# bus_station           -0.088355
# school_dist           -0.071853
# Tax                   -0.059477
# near_park_dist        -0.050178
# dist_mall             -0.042751
# floor_no              -0.040244
# swimming_pool         -0.022748
# train_station         -0.019872
# dist_local_market     -0.017403
# dist_bank             -0.015593
# dist_health_center    -0.015361
# NRM                   -0.013769
# dist_police_station   -0.002571
# area_type              0.000582
# age_of_house           0.012809
# parking_on_street      0.046591
# dist_worship           0.066735
# Price                  1.000000
# Name: Price, dtype: float64

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
dist_mall=result['dist_mall']
train_station=result['train_station']
bus_station=result['bus_station']
school_dist=result['school_dist']
dist_health_center=result['dist_health_center']
parking_on_street=result['parking_on_street']
dist_local_market=result['dist_local_market']
NRM=result['NRM']
age_of_house=result['age_of_house']
area_type=result['area_type']
floor_no=result['floor_no']
Tax=result['Tax']

# %%
type(dist_mall)
# Out:
# numpy.float64

# %%
x_data_pro=[dist_mall,train_station,bus_station,school_dist,dist_health_center,parking_on_street,dist_local_market,NRM,age_of_house,area_type,floor_no,Tax]

# %%
x_data_pro[0]
# Out:
# -0.04275093222545509

# %%
names[0]
# Out:
# 'train_station'

# %%
x_data_pro
# Out:
# [-0.04275093222545509,
#  -0.01987167861063245,
#  -0.08835501829087322,
#  -0.0718527344716434,
#  -0.015361397827317042,
#  0.0465910867674292,
#  -0.017403487881986347,
#  -0.013769167236200914,
#  0.012808750568037583,
#  0.0005820846909900289,
#  -0.040243523258781146,
#  -0.05947709490425249]

# %%
data={
    "NRM":NRM,
    "Area type":area_type,
    "Dist_mall":dist_mall,
    "Train station":train_station,
    "Bus station":bus_station,
    "Tax":Tax,
    "school_dist":school_dist,
    "hospital_dist":dist_health_center
    
}

# %%
fig = plt.figure(figsize = (10, 6))
 
# creating the bar plot
plt.xlabel("Attributes")
plt.ylabel("Dependency")
plt.title("Price dependency")


names_x = list(data.keys())
values_x = list(data.values())

plt.bar(names_x,values_x)
plt.show()

# %%
data={
"parking_on_street":parking_on_street,
"dist_local_market":dist_local_market,
"age_of_house":age_of_house,
"floor_no":floor_no,
}

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.xlabel("Attributes")
plt.ylabel("Dependency")
plt.title("Price dependency")


names_x = list(data.keys())
values_x = list(data.values())

plt.bar(names_x,values_x)
plt.show()

# %%
import numpy as np
price= np.array(df_copy['Price'])
area_type =np.array(df_copy['area_type'])

# %%
type(price)
type(area_type)
# Out:
# numpy.ndarray

# %%
y = price
x = area_type
plt.scatter(x, y)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
train_data = train_set.drop("Price", axis=1)
train_label = train_set["Price"].copy()
test_data = test_set.drop("Price", axis=1)
test_label = test_set["Price"].copy()

# %%
train_data.head
# Out:
# <bound method NDFrame.head of      swimming_pool  train_station  bus_station  school_dist  near_park_dist  \
# 249              0              5            2            4               3
# 433              1              1            1            1               5
# 19               1              4            3            3               1
# 322              0              2            4            2               3
# 332              1              2            3            2               5
# ..             ...            ...          ...          ...             ...
# 106              1              1            2            1               3
# 270              0              2            3            2               3
# 348              0              2            2            4               5
# 435              0              5            5            3               4
# 102              1              3            4            4               2
#
#      parking_on_street  dist_local_market  dist_health_center  dist_bank  NRM  \
# 249                  0                  4                   1          3    5
# 433                  1                  2                   4          4    4
# 19                   0                  1                   5          2    3
# 322                  0                  4                   2          1    3
# 332                  1                  3                   3          2    2
# ..                 ...                ...                 ...        ...  ...
# 106                  1                  4                   1          5    3
# 270                  1                  5                   4          5    1
# 348                  0                  2                   1          5    2
# 435                  0                  3                   2          4    4
# 102                  1                  5                   3          1    1
#
#       Tax  age_of_house  area_type  dist_police_station  dist_mall  floor_no  \
# 249  4449             2          0                    3          1         7
# 433  2069            10          1                    2          2        18
# 19   2019             8          0                    2          3        17
# 322  3205            20          0                    3          2        23
# 332  4062            14          0                    3          2        19
# ..    ...           ...        ...                  ...        ...       ...
# 106  3170            12          0                    3          1        28
# 270  2015            20          1                    2          3         5
# 348  3723            16          0                    3          3        24
# 435  4398             4          1                    3          1        24
# 102  2929             5          0                    1          2         6
#
#      dist_worship
# 249           208
# 433           497
# 19             90
# 322          1077
# 332           704
# ..            ...
# 106           966
# 270           473
# 348           730
# 435           959
# 102           783
#
# [400 rows x 17 columns]>

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler',StandardScaler())
])

# %%
train_set = my_pipeline.fit_transform(train_data)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
model = LinearRegression()
# model = DecisionTreeRegressor()
# model = RandomForestRegressor()
model.fit(train_set,train_label)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
test_prepared = my_pipeline.transform(test_data)
final_predictions = model.predict(test_prepared)
final_mse = mean_squared_error(test_label, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 1.1386468751254621

# %%
final_mse
# Out:
# 1.2965167062329797

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, test_prepared, test_label, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([1.47639012, 1.27546682, 1.06680752, 1.13621486, 1.05847833,
#        1.11390606, 0.99444539, 1.28515018, 0.93907256, 1.50997442])

# %%
def print_score(Scores):
    print("Score: ",Scores)
    print("Mean: ",Scores.mean())
    print("Standard deviation: ",Scores.std())

# %%
print_score(rmse_scores)
# Out:
# Score:  [1.47639012 1.27546682 1.06680752 1.13621486 1.05847833 1.11390606
#  0.99444539 1.28515018 0.93907256 1.50997442]
# Mean:  1.1855906264394251
# Standard deviation:  0.1851837729011514

# %%
import pickle

# %%
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
test_prepared
# Out:
# array([[-1.040833  ,  0.67859448, -0.67464198, ..., -1.137393  ,
#         -0.85013914,  1.66043389],
#        [ 0.96076892,  0.67859448, -1.39618421, ..., -1.137393  ,
#          1.22928803, -1.50888444],
#        [-1.040833  ,  1.37458881,  0.76844247, ...,  1.2955332 ,
#         -0.57288219,  0.66236127],
#        ...,
#        [ 0.96076892,  0.67859448, -1.39618421, ...,  0.0790701 ,
#         -1.1273961 ,  0.07285638],
#        [ 0.96076892,  0.67859448, -0.67464198, ...,  1.2955332 ,
#         -0.85013914,  0.45224071],
#        [-1.040833  , -0.71339419,  0.76844247, ...,  0.0790701 ,
#          1.64517346,  1.68378062]])

# %%
test_data
# Out:
#      swimming_pool  train_station  bus_station  school_dist  near_park_dist  \
# 218              0              1            3            3               4
# 79               1              2            2            1               1
# 104              1              1            3            3               4
# 208              1              4            3            1               1
# 543              0              2            5            1               2
# ..             ...            ...          ...          ...             ...
# 148              1              1            3            2               5
# 247              0              2            5            3               4
# 15               0              2            1            4               1
# 557              0              3            1            2               4
# 245              0              5            4            1               1
#
#      parking_on_street  dist_local_market  dist_health_center  dist_bank  NRM  \
# 218                  1                  4                   5          5    2
# 79                   1                  3                   5          5    3
# 104                  1                  1                   5          3    3
# 208                  1                  2                   5          3    2
# 543                  1                  3                   4          4    3
# ..                 ...                ...                 ...        ...  ...
# 148                  0                  5                   2          3    3
# 247                  0                  2                   1          4    2
# 15                   0                  4                   2          3    3
# 557                  0                  5                   3          4    3
# 245                  1                  3                   5          3    2
#
#       Tax  age_of_house  area_type  dist_police_station  dist_mall  floor_no  \
# 218  4880            12          0                    1          1         6
# 79   3174             2          1                    2          1         6
# 104  2524            10          1                    1          2         7
# 208  3498            15          0                    3          2         9
# 543  3380            17          0                    3          3         5
# ..    ...           ...        ...                  ...        ...       ...
# 148  4503             2          0                    1          2         9
# 247  3510             1          1                    1          1        10
# 15   4753            14          1                    1          2         5
# 557  4815             2          1                    1          2         9
# 245  3435            16          0                    2          2         8
#
#      dist_worship
# 218             3
# 79              9
# 104             9
# 208            11
# 543             4
# ..            ...
# 148            11
# 247             9
# 15              2
# 557            12
# 245             1
#
# [114 rows x 17 columns]
